# %%
import pandas as pd
import regex as re
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %%
treatment_locations= pd.read_csv("C:/Users/darin/Documents/NSS/darina_capstone/capstone/data/treatment_centers_location1.csv")
treatment_locations
# Out:
#                               Treament Center Name  \
# 0                  Talbott Legacy Center Maryville
# 1   Bradley Country Comprehensive Treatment Center
# 2                        New Hope Treatment Center
# 3                   Behavior Health Group  Madison
# 4              Behavior Health Group  Murfreesboro
# 5                 Behavior Health Group  Nashville
# 6         Hermitage Comprehensive Treatment Center
# 7   South Nashville Comprehensive Treatment Center
# 8                  Behavior Health Group Dyersburg
# 9         Volunteer Comprehensive Treatment Center
# 10                 Behavior Health Group  Savannah
# 11                     Behavior Health Group Paris
# 12                   Behavior Health Group Jackson
# 13        Behavior Health Group Knoville - Central
# 14        Behavior Health Group Knoville - Bernard
# 15                 Behavior Health Group  Columbia
# 16                    Clarksville Treatment Center
# ...

# %%
m = folium.Map(location=[36.163248089975404, -86.77152505919005], zoom_start=8)

# %%
for index, row in treatment_locations.iterrows():
    lat = row['LAT']
    lng = row['LON']
    center = row['Treament Center Name']
    popup = f"{center}<br>{row['Street Address']}<br>{row['City']}, {row['State']} {row['Zipcode']}"
    icon = folium.Icon(icon='fa-hospital', prefix='fa')  # Using Font Awesome hospital icon
    folium.Marker(location=[lat, lng], popup=popup, icon=icon).add_to(m)


m.save("treatment_centers_map.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
