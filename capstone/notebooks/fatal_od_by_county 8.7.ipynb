# %%
import pandas as pd
import regex as re
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
## reading in county od for 2019 and 2020
countyod= pd.read_csv(r'C:\Users\darin\Documents\NSS\darina_capstone\capstone\data\2019.2020 _fatalod_bycounty.csv')
countyod
# Out:
#      Year County Name GeographyType State  \
# 0    2019      Blount        County    TN
# 1    2019      Blount        County    TN
# 2    2019      Blount        County    TN
# 3    2019      Blount        County    TN
# 4    2019     Bradley        County    TN
# ..    ...         ...           ...   ...
# 107  2020      Shelby        County    TN
# 108  2020  Washington        County    TN
# 109  2020  Washington        County    TN
# 110  2020  Washington        County    TN
# 111  2020  Washington        County    TN
#
#                               Type of Overdose  Total Number of Deaths
# 0               Involving Prescription Opioids                      15
# 1                        Involving All Opioids                      34
# 2          Involving Opioids and Any Stimulant                      10
# 3    Involving All Opioids and Benzodiazepines                       3
# 4               Involving Prescription Opioids                       5
# ...

# %%
##dropping geographytype and state
countyod.drop(['GeographyType', 'State'], axis=1, inplace=True)
countyod
# Out:
#      Year County Name                           Type of Overdose  \
# 0    2019      Blount             Involving Prescription Opioids
# 1    2019      Blount                      Involving All Opioids
# 2    2019      Blount        Involving Opioids and Any Stimulant
# 3    2019      Blount  Involving All Opioids and Benzodiazepines
# 4    2019     Bradley             Involving Prescription Opioids
# ..    ...         ...                                        ...
# 107  2020      Shelby  Involving All Opioids and Benzodiazepines
# 108  2020  Washington             Involving Prescription Opioids
# 109  2020  Washington                      Involving All Opioids
# 110  2020  Washington        Involving Opioids and Any Stimulant
# 111  2020  Washington  Involving All Opioids and Benzodiazepines
#
#      Total Number of Deaths
# 0                        15
# 1                        34
# 2                        10
# 3                         3
# 4                         5
# ...

# %%
## isolating 2019 info
countyod2019= countyod.loc[countyod.Year == 2019]
countyod2019.head(1)
# Out:
#    Year County Name                Type of Overdose  Total Number of Deaths
# 0  2019      Blount  Involving Prescription Opioids                      15

# %%
countyod2019.drop(['Year'], axis=1, inplace=True)
# Out:
# C:\Users\darin\AppData\Local\Temp\ipykernel_10404\132471855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   countyod2019.drop(['Year'], axis=1, inplace=True)

# %%
countyod2019
# Out:
#    County Name                           Type of Overdose  \
# 0       Blount             Involving Prescription Opioids
# 1       Blount                      Involving All Opioids
# 2       Blount        Involving Opioids and Any Stimulant
# 3       Blount  Involving All Opioids and Benzodiazepines
# 4      Bradley             Involving Prescription Opioids
# 5      Bradley                      Involving All Opioids
# 6      Bradley        Involving Opioids and Any Stimulant
# 7      Bradley  Involving All Opioids and Benzodiazepines
# 8        Cocke             Involving Prescription Opioids
# 9        Cocke                      Involving All Opioids
# 10       Cocke        Involving Opioids and Any Stimulant
# 11       Cocke  Involving All Opioids and Benzodiazepines
# 12    Davidson             Involving Prescription Opioids
# 13    Davidson                      Involving All Opioids
# 14    Davidson        Involving Opioids and Any Stimulant
# ...

# %%
countyod2019.groupby('County Name').sum()
# Out:
# C:\Users\darin\AppData\Local\Temp\ipykernel_10404\4112768704.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   countyod2019.groupby('County Name').sum()
#              Total Number of Deaths
# County Name
# Blount                           62
# Bradley                          31
# Cocke                             7
# Davidson                        512
# Dyer                              9
# Hamilton                        134
# Hardin                            2
# Henry                            14
# Jackson                           6
# Knox                            349
# Maury                            52
# Montgomery                      105
# Shelby                          410
# Washington                       38

# %%
totaldeaths_bycounty2019 =pd.DataFrame(countyod2019.groupby('County Name').sum())
totaldeaths_bycounty2019
# Out:
# C:\Users\darin\AppData\Local\Temp\ipykernel_10404\4125863966.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   totaldeaths_bycounty2019 =pd.DataFrame(countyod2019.groupby('County Name').sum())
#              Total Number of Deaths
# County Name
# Blount                           62
# Bradley                          31
# Cocke                             7
# Davidson                        512
# Dyer                              9
# Hamilton                        134
# Hardin                            2
# Henry                            14
# Jackson                           6
# Knox                            349
# Maury                            52
# Montgomery                      105
# Shelby                          410
# Washington                       38
