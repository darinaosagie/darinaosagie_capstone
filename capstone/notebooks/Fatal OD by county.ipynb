# %%
import pandas as pd
import regex as re
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
## reading in county od for 2019 and 2020
countyod= pd.read_csv(r'C:\Users\darin\Documents\NSS\capstone\data\2019.2020  fatal od by county(cleaned).csv')
countyod
# Out:
#      Year   Geography GeographyType State  \
# 0    2019      Blount        County    TN
# 1    2019      Blount        County    TN
# 2    2019      Blount        County    TN
# 3    2019      Blount        County    TN
# 4    2019     Bradley        County    TN
# ..    ...         ...           ...   ...
# 107  2020      Shelby        County    TN
# 108  2020  Washington        County    TN
# 109  2020  Washington        County    TN
# 110  2020  Washington        County    TN
# 111  2020  Washington        County    TN
#
#                                Death Indicator  Total Number of Deaths
# 0               Involving Prescription Opioids                      15
# 1                        Involving All Opioids                      34
# 2          Involving Opioids and Any Stimulant                      10
# 3    Involving All Opioids and Benzodiazepines                       3
# 4               Involving Prescription Opioids                       5
# ...

# %%
## isolating 2019 info
od2019 = countyod.loc[countyod.Year == 2019]
od2019
# Out:
#     Year   Geography GeographyType State  \
# 0   2019      Blount        County    TN
# 1   2019      Blount        County    TN
# 2   2019      Blount        County    TN
# 3   2019      Blount        County    TN
# 4   2019     Bradley        County    TN
# 5   2019     Bradley        County    TN
# 6   2019     Bradley        County    TN
# 7   2019     Bradley        County    TN
# 8   2019       Cocke        County    TN
# 9   2019       Cocke        County    TN
# 10  2019       Cocke        County    TN
# 11  2019       Cocke        County    TN
# 12  2019    Davidson        County    TN
# 13  2019    Davidson        County    TN
# 14  2019    Davidson        County    TN
# 15  2019    Davidson        County    TN
# 16  2019        Dyer        County    TN
# 17  2019        Dyer        County    TN
# 18  2019        Dyer        County    TN
# 19  2019        Dyer        County    TN
# 20  2019    Hamilton        County    TN
# 21  2019    Hamilton        County    TN
# ...

# %%
od2019 = od2019.drop(['Year', 'GeographyType', 'State'], axis=1)

# %%
od2019
# Out:
#      Geography                            Death Indicator  \
# 0       Blount             Involving Prescription Opioids
# 1       Blount                      Involving All Opioids
# 2       Blount        Involving Opioids and Any Stimulant
# 3       Blount  Involving All Opioids and Benzodiazepines
# 4      Bradley             Involving Prescription Opioids
# 5      Bradley                      Involving All Opioids
# 6      Bradley        Involving Opioids and Any Stimulant
# 7      Bradley  Involving All Opioids and Benzodiazepines
# 8        Cocke             Involving Prescription Opioids
# 9        Cocke                      Involving All Opioids
# 10       Cocke        Involving Opioids and Any Stimulant
# 11       Cocke  Involving All Opioids and Benzodiazepines
# 12    Davidson             Involving Prescription Opioids
# 13    Davidson                      Involving All Opioids
# 14    Davidson        Involving Opioids and Any Stimulant
# ...

# %%
od2019.rename(columns={'Geography': 'County', 'Death Indicator': 'Type of Fatal Overdose'}, inplace=True)
od2019.head(1)
# Out:
#    County          Type of Fatal Overdose  Total Number of Deaths
# 0  Blount  Involving Prescription Opioids                      15

# %%
od2019.groupby('County').sum()
# Out:
# C:\Users\darin\AppData\Local\Temp\ipykernel_21960\1211113863.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   od2019.groupby('County').sum()
#             Total Number of Deaths
# County
# Blount                          62
# Bradley                         31
# Cocke                            7
# Davidson                       512
# Dyer                             9
# Hamilton                       134
# Hardin                           2
# Henry                           14
# Jackson                          6
# Knox                           349
# Maury                           52
# Montgomery                     105
# Shelby                         410
# Washington                      38

# %%
totaldeaths_bycounty2019 =pd.DataFrame(od2019.groupby('County').sum())
totaldeaths_bycounty2019
# Out:
# C:\Users\darin\AppData\Local\Temp\ipykernel_21960\2998431431.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   totaldeaths_bycounty2019 =pd.DataFrame(od2019.groupby('County').sum())
#             Total Number of Deaths
# County
# Blount                          62
# Bradley                         31
# Cocke                            7
# Davidson                       512
# Dyer                             9
# Hamilton                       134
# Hardin                           2
# Henry                           14
# Jackson                          6
# Knox                           349
# Maury                           52
# Montgomery                     105
# Shelby                         410
# Washington                      38

# %%
totaldeaths_bycounty2019=totaldeaths_bycounty2019.reset_index()
totaldeaths_bycounty2019
# Out:
#         County  Total Number of Deaths
# 0       Blount                      62
# 1      Bradley                      31
# 2        Cocke                       7
# 3     Davidson                     512
# 4         Dyer                       9
# 5     Hamilton                     134
# 6       Hardin                       2
# 7        Henry                      14
# 8      Jackson                       6
# 9         Knox                     349
# 10       Maury                      52
# 11  Montgomery                     105
# 12      Shelby                     410
# 13  Washington                      38

# %%
totaldeaths_bycounty2019.sort_values(by = 'Total Number of Deaths', ascending = False)
# Out:
#         County  Total Number of Deaths
# 3     Davidson                     512
# 12      Shelby                     410
# 9         Knox                     349
# 5     Hamilton                     134
# 11  Montgomery                     105
# 0       Blount                      62
# 10       Maury                      52
# 13  Washington                      38
# 1      Bradley                      31
# 7        Henry                      14
# 4         Dyer                       9
# 2        Cocke                       7
# 8      Jackson                       6
# 6       Hardin                       2

# %%
od2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56 entries, 0 to 55
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   County                  56 non-null     object
#  1   Type of Fatal Overdose  56 non-null     object
#  2   Total Number of Deaths  56 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.8+ KB

# %%
od2019.groupby('Type of Fatal Overdose')

# %%
od2019.describe()
# Out:
#        Total Number of Deaths
# count               56.000000
# mean                30.910714
# std                 54.008173
# min                  0.000000
# 25%                  2.750000
# 50%                  8.500000
# 75%                 34.250000
# max                280.000000

# %%
## isolating 2020 info
od2020 = countyod.loc[countyod.Year == 2020]
od2020.head(1)
# Out:
#     Year Geography GeographyType State                 Death Indicator  \
# 56  2020    Blount        County    TN  Involving Prescription Opioids
#
#     Total Number of Deaths
# 56                       4

# %%
od2020 = od2020.drop(['Year', 'GeographyType', 'State'], axis=1)

# %%
od2020
# Out:
#       Geography                            Death Indicator  \
# 56       Blount             Involving Prescription Opioids
# 57       Blount                      Involving All Opioids
# 58       Blount        Involving Opioids and Any Stimulant
# 59       Blount  Involving All Opioids and Benzodiazepines
# 60      Bradley             Involving Prescription Opioids
# 61      Bradley                      Involving All Opioids
# 62      Bradley        Involving Opioids and Any Stimulant
# 63      Bradley  Involving All Opioids and Benzodiazepines
# 64        Cocke             Involving Prescription Opioids
# 65        Cocke                      Involving All Opioids
# 66        Cocke        Involving Opioids and Any Stimulant
# 67        Cocke  Involving All Opioids and Benzodiazepines
# 68     Davidson             Involving Prescription Opioids
# 69     Davidson                      Involving All Opioids
# 70     Davidson        Involving Opioids and Any Stimulant
# ...

# %%
od2020.rename(columns={'Geography': 'County', 'Death Indicator': 'Type of Fatal Overdose'}, inplace=True)
od2020.head(1)
# Out:
#     County          Type of Fatal Overdose  Total Number of Deaths
# 56  Blount  Involving Prescription Opioids                       4

# %%
od2020.groupby('County').sum()
# Out:
# C:\Users\darin\AppData\Local\Temp\ipykernel_21960\1198010478.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   od2020.groupby('County').sum()
#             Total Number of Deaths
# County
# Blount                          63
# Bradley                         33
# Cocke                           18
# Davidson                       726
# Dyer                             3
# Hamilton                       168
# Hardin                          23
# Henry                           13
# Jackson                         11
# Knox                           490
# Maury                           48
# Montgomery                     142
# Shelby                         717
# Washington                      58

# %%
totaldeaths_bycounty2020 =pd.DataFrame(od2020.groupby('County').sum())
totaldeaths_bycounty2020
# Out:
# C:\Users\darin\AppData\Local\Temp\ipykernel_21960\795193046.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   totaldeaths_bycounty2020 =pd.DataFrame(od2020.groupby('County').sum())
#             Total Number of Deaths
# County
# Blount                          63
# Bradley                         33
# Cocke                           18
# Davidson                       726
# Dyer                             3
# Hamilton                       168
# Hardin                          23
# Henry                           13
# Jackson                         11
# Knox                           490
# Maury                           48
# Montgomery                     142
# Shelby                         717
# Washington                      58

# %%
totaldeaths_bycounty2020=totaldeaths_bycounty2020.reset_index()
totaldeaths_bycounty2020
# Out:
#         County  Total Number of Deaths
# 0       Blount                      63
# 1      Bradley                      33
# 2        Cocke                      18
# 3     Davidson                     726
# 4         Dyer                       3
# 5     Hamilton                     168
# 6       Hardin                      23
# 7        Henry                      13
# 8      Jackson                      11
# 9         Knox                     490
# 10       Maury                      48
# 11  Montgomery                     142
# 12      Shelby                     717
# 13  Washington                      58

# %%
totaldeaths_bycounty2020.sort_values(by = 'Total Number of Deaths', ascending = False) ## total deaths by county for 2020
# Out:
#         County  Total Number of Deaths
# 3     Davidson                     726
# 12      Shelby                     717
# 9         Knox                     490
# 5     Hamilton                     168
# 11  Montgomery                     142
# 0       Blount                      63
# 13  Washington                      58
# 10       Maury                      48
# 1      Bradley                      33
# 6       Hardin                      23
# 2        Cocke                      18
# 7        Henry                      13
# 8      Jackson                      11
# 4         Dyer                       3

# %%
od2020.describe()
# Out:
#        Total Number of Deaths
# count               56.000000
# mean                44.875000
# std                 84.093468
# min                  0.000000
# 25%                  3.000000
# 50%                 10.000000
# 75%                 38.750000
# max                395.000000
